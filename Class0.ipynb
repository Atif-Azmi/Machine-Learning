# %% [markdown]
# <a href="https://colab.research.google.com/github/Atif-Azmi/Machine-Learning/blob/main/Class0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d omkargurav/face-mask-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/omkargurav/face-mask-dataset
# License(s): unknown
# ...
# 100% 163M/163M [00:00<00:00, 189MB/s]

# %%
import zipfile

# Replace 'your_file_name.zip' with the actual name of your file
zip_ref = zipfile.ZipFile('face-mask-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

print("Extraction completed successfully!")
# Out:
# Extraction completed successfully!
